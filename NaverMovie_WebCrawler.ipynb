# %%
from bs4 import BeautifulSoup
from selenium import webdriver

import sys
import re
import math
import numpy  
import pandas as pd 
import os

query_txt = input('1.크롤링 할 영화의 제목을 입력하세요: ')
query_url = 'https://movie.naver.com'

cnt = int(input('2.크롤링 할 리뷰건수는 몇건입니까?: '))
page_cnt = math.ceil(cnt / 10)

f_dir = input("3.파일을 저장할 폴더명만 쓰세요(예:c:\\temp\\):")

f_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.txt'
fc_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.csv'
fx_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.xls'

path = "c:/temp/chromedriver_240/chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get(query_url)
time.sleep(2)

element = driver.find_element_by_id("ipt_tx_srch")
element.send_keys(query_txt)
driver.find_element_by_xpath("""//*[@id="jSearchArea"]/div/button""").click()
driver.find_element_by_xpath("""//*[@id="old_content"]/ul[2]/li/dl/dt/a""").click()
        
driver.find_element_by_link_text("평점").click()

driver.switch_to.frame('pointAfterListIframe')

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

page_cnt = math.ceil(cnt / 10)

score2=[]
review2=[]
name2=[]
date2=[]
like_list=[]
like2=[]
dislike2=[]
dwlist2=[]

count = 0         
click_count = 1   

while ( click_count <= page_cnt )  :
            
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            
            score_result = soup.find('div', class_='score_result').find('ul')
            slist = score_result.find_all('li')

            for li in slist:

                count += 1
                
                f = open(ff_name, 'a',encoding='UTF-8')
            
                score = li.find('div', class_='star_score').find('em').get_text()
                print("1.별점:","*"*int(score),": ", score)
                score2.append(score)
                f.write("\n")
                f.write("1.별점:"+score + "\n")
            
                review = li.find('div', class_='score_reple').find('p').get_text()
                print("2. 리뷰내용:",review)
                f.write("2. 리뷰내용:" + review + "\n")
                review2.append(review)
         
                dwlist = li.find('div',class_='score_reple').find_all('em')
                name = dwlist[0].find('span').get_text()
                print("3. 작성자:",name)
                f.write("3. 작성자:" + name + "\n")
                name2.append(name)
                
                date = dwlist[1].text
                print('4. 작성일자:',date)
                f.write("4. 작성일자:" + date + "\n")
                date2.append(date)
            
                like_list = li.find('div', class_='btn_area').find_all('strong')
                like = like_list[0].text
                print('5. 공감:',like)
                f.write("5. 공감:" + like + "\n")
                like2.append(like)
                
                dislike = like_list[1].text
                print('6. 비공감:', dislike)
                f.write("6. 비공감:" + dislike + "\n")
                dislike2.append(dislike)
                print("\n")

                if count == cnt :
                    break

            click_count += 1
            
            if click_count > page_cnt :
                break
            else :
                driver.find_element_by_link_text("%s" %click_count).click()

naver_movie = pd.DataFrame()
naver_movie['별점']=score2
naver_movie['리뷰 내용']=review2
naver_movie['작성자']=name2
naver_movie['작성일자']=date2
naver_movie['공감 횟수']=like2
naver_movie['비공감 횟수']=dislike2

# csv 저장
naver_movie.to_csv(fc_name,encoding="utf-8-sig",index=True)

# xls 저장
naver_movie.to_excel(fx_name ,index=True)

print("1.파일 저장 완료: txt 파일명 : %s " %f_name)
print("2.파일 저장 완료: csv 파일명 : %s " %fc_name)
print("3.파일 저장 완료: xls 파일명 : %s " %fx_name)

driver.close( )
# Out:
# 1.크롤링 할 영화의 제목을 입력하세요: 분노의 질주
# 2.크롤링 할 리뷰건수는 몇건입니까?: 20
# 3.파일을 저장할 폴더명만 쓰세요(예:c:\temp\):c:\temp
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																뇌를 비우고 즐기면 된다
#
#
#
#
#
# 3. 작성자: 테드(gado****)
# 4. 작성일자: 2021.05.19 13:06
# 5. 공감: 1214
# 6. 비공감: 111
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																시리즈 팬들에게 주는 선물 같았던 엔딩..크.... 아련아련 ㅜㅜ
#
#
#
#
#
# 3. 작성자: 됴롱(gusr****)
# 4. 작성일자: 2021.05.19 10:45
# 5. 공감: 747
# 6. 비공감: 75
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																역시 분노의 질주! 이런 블록버스터는 역시 극장에서 봐야지
#
#
#
#
#
# 3. 작성자: high****
# 4. 작성일자: 2021.05.19 10:43
# 5. 공감: 693
# 6. 비공감: 98
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																와 오랜만에 극장에서 봤는데 스케일 도랐 액션 개쩜
#
#
#
#
#
# 3. 작성자: 로다쥬(yj05****)
# 4. 작성일자: 2021.05.19 10:47
# 5. 공감: 639
# 6. 비공감: 89
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																티라노사우루스는 팔이 짧아 분노의 질주 꿀잼 액션을 보고도 박수를 못쳐서 멸종됐다.
#
#
#
#
#
# 3. 작성자: gmlw****
# 4. 작성일자: 2021.05.19 10:47
# 5. 공감: 712
# 6. 비공감: 175
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
# 스포일러가 포함된 감상평입니다. 감상평 보기
#
#
#
#
# 																전작까지는 우주빼고 안가본데가 없었는데 이제 우주까지 나가네요..
#
#
#
#
#
# 3. 작성자: Song UG(song****)
# 4. 작성일자: 2021.05.19 12:22
# 5. 공감: 564
# 6. 비공감: 51
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																졸라 신난다 진짜ㅋㅋㅋ 아 아침 일찍 보고 왔는데 보람있군
#
#
#
#
#
# 3. 작성자: 강은정(zer5****)
# 4. 작성일자: 2021.05.19 12:05
# 5. 공감: 555
# 6. 비공감: 64
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																저스틴 린 감독이 진짜 오리지널 감독이긴 하네. 진짜 <분노의 질주> 시리즈 보는 것 같음!!!!
#
#
#
#
#
# 3. 작성자: Hailey(hyel****)
# 4. 작성일자: 2021.05.19 10:46
# 5. 공감: 510
# 6. 비공감: 61
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																진짜 상상이상의 액션ㅋㅋㅋㅋ 아직 안본 분들 정말 상상도 못하셨을 겁니다
#
#
#
#
#
# 3. 작성자: 고니(lepa****)
# 4. 작성일자: 2021.05.19 12:54
# 5. 공감: 484
# 6. 비공감: 52
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																너무 재미있었어요~~ 기다린 보람이 있었어요 다음편두 더 기대할게요
#
#
#
#
#
# 3. 작성자: 문종칠(whdc****)
# 4. 작성일자: 2021.05.19 11:12
# 5. 공감: 438
# 6. 비공감: 52
#
#
# 1.별점: ******** :  8
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																마지막 닛산 스카이 라인이 나오는 장면 만으로도 이 영화는 가치가 있다
#
#
#
#
#
# 3. 작성자: 천재소년98(mond****)
# 4. 작성일자: 2021.05.19 14:22
# 5. 공감: 348
# 6. 비공감: 14
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
#
#
#
#
#
# 																CGV 수원 조조 6시30분 전 세계 최초 관람하고 댓 남깁니다 와 이번꺼 액션 장난 아님 무조건 극장에서 봐야함 빡빡이 2명이 빠져서 아쉽지만 그래도 다른 배우들이 한 몫했음 쿠키도 있으니 챙겨보길 바람
#
#
#
#
#
# 3. 작성자: Abc123(fowe****)
# 4. 작성일자: 2021.05.19 09:12
# 5. 공감: 351
# 6. 비공감: 21
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																빈 디젤은 세월이 이렇게 많이 흘렀는데도 전혀 나이 먹지 않은 느낌이다.. 진짜 멋짐bb
#
#
#
#
#
# 3. 작성자: 이영람(rsls****)
# 4. 작성일자: 2021.05.19 23:34
# 5. 공감: 333
# 6. 비공감: 9
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
#
#
#
#
#
# 																흐엉...ㅠㅠ 너무 그리웠고 너무 반가웠어요!극장 자리에 딱 앉았을 때의 기분을 얼마나 느끼고 싶었었는지..! 휴 포스터 들고 코로나 병맥 사 들고 집에 갑니다.
#
#
#
#
#
# 3. 작성자: hell****
# 4. 작성일자: 2021.05.19 09:49
# 5. 공감: 334
# 6. 비공감: 12
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																분노의질주 시리즈는 무조건 극장에서 봐야 함
#
#
#
#
#
# 3. 작성자: 양다일 사랑해(ma3y****)
# 4. 작성일자: 2021.05.19 13:58
# 5. 공감: 329
# 6. 비공감: 11
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
#
#
#
#
#
# 																역시는 역시다! 이런 블록버스터를 극장에서 본게 얼마만이냐 대체 ㅎㅎㅎ
#
#
#
#
#
# 3. 작성자: jydo****
# 4. 작성일자: 2021.05.19 09:19
# 5. 공감: 327
# 6. 비공감: 10
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																역시 분노의 질주! 엄청난 스케일과 함께 좋은 노래들이 많아서 잘 봤습니다! 마지막 쿠키영상까지 짱이었습니다!
#
#
#
#
#
# 3. 작성자: 다인(myda****)
# 4. 작성일자: 2021.05.19 16:30
# 5. 공감: 328
# 6. 비공감: 11
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																화끈하네요 시간가는줄 몰랐어요멋지네
#
#
#
#
#
# 3. 작성자: 호반장(ljhg****)
# 4. 작성일자: 2021.05.19 16:44
# 5. 공감: 323
# 6. 비공감: 10
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
# 관람객
#
#
#
#
#
# 																분노의질주는 역시 짱이네요 신나는 액션으로 너무 재밌게 보고 왔습니다
#
#
#
#
#
# 3. 작성자: 송유선(h2ts****)
# 4. 작성일자: 2021.05.19 12:44
# 5. 공감: 325
# 6. 비공감: 12
#
#
# 1.별점: ********** :  10
# 2. 리뷰내용:
#
#
#
#
#
# 																그냥 최고임 다시 봐야지
#
#
#
#
#
# 3. 작성자: 김현제(hyun****)
# 4. 작성일자: 2021.05.19 09:20
# 5. 공감: 321
# 6. 비공감: 10
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-ed1aa9c581d6> in <module>
#     120
#     121 # csv 저장
# --> 122 naver_movie.to_csv(fc_name,encoding="utf-8-sig",index=True)
#     123
#     124 # xls 저장
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\temp2021-06-08-16-49-18-분노의 질주\\2021-06-08-16-49-18-분노의 질주.csv'
